# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder

# %%
workflows_df = pd.read_pickle("../dumps/workflows_df.pkl")
actions_df = pd.read_pickle("../dumps/actions_df.pkl")
frequent_actions_df = pd.read_pickle("../dumps/frequent_actions_df.pkl")
frequent_actions_noTags_df = pd.read_pickle("../dumps/frequent_actions_noTags_df.pkl")
frequent_docker_commands_subsample_df = pd.read_pickle("../dumps/frequent_docker_commands_subsample_df.pkl")
frequent_cml_commands_subsample_df = pd.read_pickle("../dumps/frequent_cml_commands_subsample_df.pkl")

# %%
def mine_frequent_patterns(
    transactions: list[list], support: float
) -> pd.DataFrame:
    te = TransactionEncoder()
    encoding = te.fit(transactions).transform(transactions)
    encoding_df = pd.DataFrame(encoding, columns=te.columns_)
    frequent_itemsets = apriori(encoding_df, min_support=support, use_colnames=True)
    frequent_itemsets["length"] = frequent_itemsets["itemsets"].apply(
        lambda x: len(x)
    )
    return frequent_itemsets

# %% [markdown]
# # RQ1 – How common is workflow automation in ML-enabled systems hosted on GitHub?
#
# Number of workflows per repository

# %%
workflows_df.groupby("repository").count()["path"].describe()
# Out:
# count    29.000000
# mean      1.310345
# std       0.806379
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       4.000000
# Name: path, dtype: float64

# %%
workflows_df["path"] = workflows_df["repository"] + "/" + workflows_df["filename"]
workflows_df["path"].unique().shape
# Out:
# (38,)

# %% [markdown]
# ## RQ 2 – What type of events are used to trigger MLOps workflows?
#
# Non è scontato che i wf vengano attivati da push x' un wf dovrebbe re-innescare l'intero processi di addestramento del modello.
# controllare i branch.
# i due casi Educational, uno solo su branch main, il blog sempre (attn. se pipeline di model building e' time consuming.)
#
# sembra che la PR non sia usata come trigger per re-innescare il retraining del modello, che è strano perche' cml ha comandi specifico.

# %%
transactions = workflows_df['trigger_events'].tolist()
patterns_df = mine_frequent_patterns(transactions, support=0.05)
patterns_df.sort_values(by="support", ascending=False)
# Out:
#     support              itemsets  length
# 2  0.789474                (push)       1
# 1  0.184211        (pull_request)       1
# 5  0.131579  (push, pull_request)       2
# 0  0.078947       (issue_comment)       1
# 3  0.052632             (release)       1
# 4  0.052632            (schedule)       1

# %%
workflows_df
# Out:
#                                            repository            filename  \
# 0                    AscendNTNU/perception_testing_21          mainci.yml
# 1                    AscendNTNU/perception_testing_21             cml.yml
# 2                                 YannickLecroart/pmr             cml.yml
# 3                        YannickLecroart/pmr_dvc_demo             cml.yml
# 4                    YannickLecroart/pmr_cml_pipeline             cml.yml
# 5                                 2796gaurav/automate  docker_destroy.yml
# 6                                 2796gaurav/automate      cml_report.yml
# 7                                 2796gaurav/automate       dockerize.yml
# 8                                 2796gaurav/automate          deploy.yml
# 9                                        akdsingh/cml             cml.yml
# 10                                  akdsingh/cml_data             cml.yml
# 11                          tue-5ARA0/mlops-demo-live             cml.yml
# 12                                  hacheemaster/wine             cml.yml
# 13               hurshd0/train_ml_with_github_actions             cml.yml
# 14                                  cheesama/morphine             cml.yml
# 15                                    MaSobkowiak/IUM             cml.yml
# 16  amitvkulkarni/Bring-DevOps-to-Machine-Learning...             cml.yml
# 17                      j-cunanan/git-action-examples             cml.yml
# 18                        CasualModel/CancerCausality             cml.yml
# 19                        CasualModel/CancerCausality           tests.yml
# 20                                Maelaf/abtest-mlops            main.yml
# 21         RakeshKumar045/MLOPS-Github-CI-CD-ML-Model  python-publish.yml
# 22         RakeshKumar045/MLOPS-Github-CI-CD-ML-Model        raka-cml.yml
# 23                        faithccd/github-actions-cml             cml.yml
# 24  luelhagos/Pharmaceutical-Sales-prediction-acro...             cml.yml
# 25                             luelhagos/abtest-mlops             cml.yml
# 26                               drforester/mlops_666             cml.yml
# 27                              ArilessTir/MLOPS_wine             cml.yml
# 28            DavidGOrtega/terraform-provider-tpitest         release.yml
# 29            DavidGOrtega/terraform-provider-tpitest            test.yml
# 30            DavidGOrtega/terraform-provider-tpitest   build-cml-ami.yml
# 31            DavidGOrtega/terraform-provider-tpitest           smoke.yml
# 32                       daheek9/github-actions-cml-2             cml.yml
# 33                   mozartofmath/AmharicSpeechToText             cml.yml
# 34                     ibrahimkaratas88/cml_base_case             cml.yml
# 35                     ibrahimkaratas88/cml_cloud_try             cml.yml
# 36                  SungminKo-smko/github-actions-cml             cml.yml
# 37                         Theehawau/Sales-Prediction             cml.yml
#
#                             name                           trigger_events  \
# 0                   PerceptionCI                     [push, pull_request]
# 1                            cml                     [push, pull_request]
# 2                      model-CHD                                   [push]
# 3                      model-CHD                                   [push]
# 4           PMR-CML-DVC-Pipeline                                   [push]
# 5           Docker Image destroy                          [issue_comment]
# 6                     cml-report                                   [push]
# 7                Docker Image CI                          [issue_comment]
# 8                  deploy to aws                          [issue_comment]
# 9                Model Selection                                   [push]
# 10               Model Selection                                   [push]
# 11                train-my-model  [push, pull_request, workflow_dispatch]
# 12            model-wine-quality                                   [push]
# 13  Titanic Model - train & test                           [pull_request]
# 14                   Model Train                                   [push]
# 15                    train_eval                                   [push]
# 16                     model-CHD                                   [push]
# 17                model-training                           [pull_request]
# 18               CancerCausality                                   [push]
# 19               CancerCausality                                   [push]
# 20      Python-Package-Structure                                   [push]
# 21               rakesh-ml-ci-cd                                [release]
# 22               Docker Image CI                     [push, pull_request]
# 23                model-training                                   [push]
# 24                          None                                   [push]
# 25                          None                                   [push]
# 26                train-my-model                                   [push]
# 27            model-wine-quality                                   [push]
# 28                       Release                                [release]
# 29                          Test           [push, pull_request, schedule]
# 30                 build-cml-ami                                   [push]
# 31                    Smoke Test          [pull_request_target, schedule]
# 32                model-training                                   [push]
# 33                          None                                   [push]
# 34                train-my-model                                   [push]
# 35                train-my-model                                   [push]
# 36                model-training                                   [push]
# 37                model-training                                   [push]
#
#     n_of_actions  cml_related_actions  docker_related_actions  \
# 0              5                False                   False
# 1              4                False                   False
# 2              1                False                   False
# 3              1                False                   False
# 4              1                False                   False
# 5              2                False                   False
# 6              4                 True                   False
# 7              3                False                   False
# 8              3                False                   False
# 9              3                 True                   False
# 10             3                 True                   False
# 11             4                 True                   False
# 12             1                False                   False
# 13             2                False                   False
# 14             1                False                   False
# 15             3                 True                   False
# 16             1                False                   False
# 17             3                 True                   False
# 18             2                 True                   False
# 19             2                 True                   False
# 20             1                False                   False
# 21             3                False                   False
# 22             1                False                   False
# 23             3                 True                   False
# 24             2                 True                   False
# 25             2                 True                   False
# 26             3                 True                   False
# 27             1                False                   False
# 28             4                False                   False
# 29             4                False                   False
# 30             1                False                   False
# 31             5                False                   False
# 32             3                 True                   False
# 33             2                 True                   False
# 34             3                 True                   False
# 35             4                 True                   False
# 36             3                 True                   False
# 37             3                 True                   False
#
#     n_of_run_commands  cml_related_commands                     cml_commands  \
# 0                   0                 False                               []
# 1                   0                 False                               []
# 2                   1                  True          [publish, send-comment]
# 3                   1                  True                   [send-comment]
# 4                   1                  True          [publish, send-comment]
# 5                   4                 False                               []
# 6                   1                  True          [publish, send-comment]
# 7                   5                 False                               []
# 8                   3                 False                               []
# 9                   1                  True          [publish, send-comment]
# 10                  1                  True          [publish, send-comment]
# 11                  1                  True                   [send-comment]
# 12                  1                  True          [publish, send-comment]
# 13                  2                  True          [publish, send-comment]
# 14                  1                  True  [tensorboard-dev, send-comment]
# 15                  1                  True          [publish, send-comment]
# 16                  1                  True          [publish, send-comment]
# 17                  1                  True                   [send-comment]
# 18                  1                  True                   [send-comment]
# 19                  3                  True                   [send-comment]
# 20                  2                 False                               []
# 21                  2                 False                               []
# 22                  1                  True          [publish, send-comment]
# 23                  1                  True          [publish, send-comment]
# 24                  2                  True                   [send-comment]
# 25                  2                  True                   [send-comment]
# 26                  1                  True          [publish, send-comment]
# 27                  1                  True          [publish, send-comment]
# 28                  3                 False                               []
# 29                  2                 False                               []
# 30                  1                  True                               []
# 31                  7                 False                               []
# 32                  1                  True          [publish, send-comment]
# 33                  2                  True                   [send-comment]
# 34                  1                  True          [publish, send-comment]
# 35                  2                  True  [runner, publish, send-comment]
# 36                  1                  True          [publish, send-comment]
# 37                  1                  True                   [send-comment]
#
#     docker_related_commands docker_commands
# 0                     False              []
# 1                     False              []
# 2                     False              []
# 3                     False              []
# 4                     False              []
# 5                     False              []
# 6                     False              []
# 7                      True   [build, push]
# 8                     False              []
# 9                     False              []
# 10                    False              []
# 11                    False              []
# 12                    False              []
# 13                    False              []
# 14                    False              []
# 15                    False              []
# 16                    False              []
# 17                    False              []
# 18                    False              []
# 19                    False              []
# 20                    False              []
# 21                    False              []
# 22                    False              []
# 23                    False              []
# 24                    False              []
# 25                    False              []
# 26                    False              []
# 27                    False              []
# 28                    False              []
# 29                    False              []
# 30                    False              []
# 31                    False              []
# 32                    False              []
# 33                    False              []
# 34                    False              []
# 35                    False              []
# 36                    False              []
# 37                    False              []

# %%
workflows_df.loc[workflows_df.cml_related_actions | workflows_df.cml_related_commands].trigger_events.value_counts()
# Out:
# [push]                                     24
# [pull_request]                              2
# [push, pull_request, workflow_dispatch]     1
# [push, pull_request]                        1
# Name: trigger_events, dtype: int64

# %% [markdown]
# ## RQ 3
# RQ3. What are the most frequently executed tasks?
#
# (Are there any sets of tasks that typically co-occur in workflows?)

# %%
frequent_actions_noTags_df.to_excel("../dumps/frequent_actions_noTags_df.xlsx")
frequent_actions_noTags_df
# Out:
#      support                                           itemsets  length
# 0   1.000000                                 (actions/checkout)       1
# 1   0.078947                                 (actions/setup-go)       1
# 2   0.368421                             (actions/setup-python)       1
# 3   0.105263            (aws-actions/configure-aws-credentials)       1
# 4   0.473684                              (iterative/setup-cml)       1
# 5   0.052632                              (iterative/setup-dvc)       1
# 6   0.052632                     (ros-industrial/industrial_ci)       1
# 7   0.078947               (actions/setup-go, actions/checkout)       2
# 8   0.368421           (actions/checkout, actions/setup-python)       2
# 9   0.105263  (aws-actions/configure-aws-credentials, action...       2
# 10  0.473684            (iterative/setup-cml, actions/checkout)       2
# 11  0.052632            (iterative/setup-dvc, actions/checkout)       2
# 12  0.052632   (ros-industrial/industrial_ci, actions/checkout)       2
# 13  0.342105        (iterative/setup-cml, actions/setup-python)       2
# 14  0.052632        (iterative/setup-dvc, actions/setup-python)       2
# 15  0.052632         (iterative/setup-dvc, iterative/setup-cml)       2
# 16  0.342105  (iterative/setup-cml, actions/checkout, action...       3
# 17  0.052632  (iterative/setup-dvc, actions/checkout, action...       3
# 18  0.052632  (iterative/setup-dvc, iterative/setup-cml, act...       3
# 19  0.052632  (iterative/setup-dvc, iterative/setup-cml, act...       3
# 20  0.052632  (iterative/setup-dvc, iterative/setup-cml, act...       4

# %% [markdown]
# Gli unici command sono di aggiornamento delle PR/commit, per aggiungere testo o immagini
# Si nota dai comandi di CML che non esiste un comando nativo per il deploy di modelli o archiviazione in un registry esterno, quali MLFlow.
# Per il secondo, non abbiamo trovato negli script riferimenti ad altre tecnologie esistenti.
# Per il primo punto si usa docker?

# %%
frequent_cml_commands_subsample_df
# Out:
#    support                 itemsets  length
# 0  0.62963                (publish)       1
# 1  1.00000           (send-comment)       1
# 2  0.62963  (send-comment, publish)       2

# %% [markdown]
# Quanti sono i wf contenenti almeno un comando CML? 28

# %%
workflows_df.loc[workflows_df.cml_related_commands].shape[0]
# Out:
# 28

# %% [markdown]
# Quanti wf contengono almeno un comando docker? 1

# %%
workflows_df.loc[workflows_df.docker_related_commands].shape[0]
# Out:
# 1

# %%
frequent_docker_commands_subsample_df
# Out:
#                                            repository            filename  \
# 0                    AscendNTNU/perception_testing_21          mainci.yml
# 1                    AscendNTNU/perception_testing_21             cml.yml
# 2                                 YannickLecroart/pmr             cml.yml
# 3                        YannickLecroart/pmr_dvc_demo             cml.yml
# 4                    YannickLecroart/pmr_cml_pipeline             cml.yml
# 5                                 2796gaurav/automate  docker_destroy.yml
# 6                                 2796gaurav/automate      cml_report.yml
# 7                                 2796gaurav/automate       dockerize.yml
# 8                                 2796gaurav/automate          deploy.yml
# 9                                        akdsingh/cml             cml.yml
# 10                                  akdsingh/cml_data             cml.yml
# 11                          tue-5ARA0/mlops-demo-live             cml.yml
# 12                                  hacheemaster/wine             cml.yml
# 13               hurshd0/train_ml_with_github_actions             cml.yml
# 14                                  cheesama/morphine             cml.yml
# 15                                    MaSobkowiak/IUM             cml.yml
# 16  amitvkulkarni/Bring-DevOps-to-Machine-Learning...             cml.yml
# 17                      j-cunanan/git-action-examples             cml.yml
# 18                        CasualModel/CancerCausality             cml.yml
# 19                        CasualModel/CancerCausality           tests.yml
# 20                                Maelaf/abtest-mlops            main.yml
# 21         RakeshKumar045/MLOPS-Github-CI-CD-ML-Model  python-publish.yml
# 22         RakeshKumar045/MLOPS-Github-CI-CD-ML-Model        raka-cml.yml
# 23                        faithccd/github-actions-cml             cml.yml
# 24  luelhagos/Pharmaceutical-Sales-prediction-acro...             cml.yml
# 25                             luelhagos/abtest-mlops             cml.yml
# 26                               drforester/mlops_666             cml.yml
# 27                              ArilessTir/MLOPS_wine             cml.yml
# 28            DavidGOrtega/terraform-provider-tpitest         release.yml
# 29            DavidGOrtega/terraform-provider-tpitest            test.yml
# 30            DavidGOrtega/terraform-provider-tpitest   build-cml-ami.yml
# 31            DavidGOrtega/terraform-provider-tpitest           smoke.yml
# 32                       daheek9/github-actions-cml-2             cml.yml
# 33                   mozartofmath/AmharicSpeechToText             cml.yml
# 34                     ibrahimkaratas88/cml_base_case             cml.yml
# 35                     ibrahimkaratas88/cml_cloud_try             cml.yml
# 36                  SungminKo-smko/github-actions-cml             cml.yml
# 37                         Theehawau/Sales-Prediction             cml.yml
#
#                             name                           trigger_events  \
# 0                   PerceptionCI                     [push, pull_request]
# 1                            cml                     [push, pull_request]
# 2                      model-CHD                                   [push]
# 3                      model-CHD                                   [push]
# 4           PMR-CML-DVC-Pipeline                                   [push]
# 5           Docker Image destroy                          [issue_comment]
# 6                     cml-report                                   [push]
# 7                Docker Image CI                          [issue_comment]
# 8                  deploy to aws                          [issue_comment]
# 9                Model Selection                                   [push]
# 10               Model Selection                                   [push]
# 11                train-my-model  [push, pull_request, workflow_dispatch]
# 12            model-wine-quality                                   [push]
# 13  Titanic Model - train & test                           [pull_request]
# 14                   Model Train                                   [push]
# 15                    train_eval                                   [push]
# 16                     model-CHD                                   [push]
# 17                model-training                           [pull_request]
# 18               CancerCausality                                   [push]
# 19               CancerCausality                                   [push]
# 20      Python-Package-Structure                                   [push]
# 21               rakesh-ml-ci-cd                                [release]
# 22               Docker Image CI                     [push, pull_request]
# 23                model-training                                   [push]
# 24                          None                                   [push]
# 25                          None                                   [push]
# 26                train-my-model                                   [push]
# 27            model-wine-quality                                   [push]
# 28                       Release                                [release]
# 29                          Test           [push, pull_request, schedule]
# 30                 build-cml-ami                                   [push]
# 31                    Smoke Test          [pull_request_target, schedule]
# 32                model-training                                   [push]
# 33                          None                                   [push]
# 34                train-my-model                                   [push]
# 35                train-my-model                                   [push]
# 36                model-training                                   [push]
# 37                model-training                                   [push]
#
#     n_of_actions  cml_related_actions  docker_related_actions  \
# 0              5                False                   False
# 1              4                False                   False
# 2              1                False                   False
# 3              1                False                   False
# 4              1                False                   False
# 5              2                False                   False
# 6              4                 True                   False
# 7              3                False                   False
# 8              3                False                   False
# 9              3                 True                   False
# 10             3                 True                   False
# 11             4                 True                   False
# 12             1                False                   False
# 13             2                False                   False
# 14             1                False                   False
# 15             3                 True                   False
# 16             1                False                   False
# 17             3                 True                   False
# 18             2                 True                   False
# 19             2                 True                   False
# 20             1                False                   False
# 21             3                False                   False
# 22             1                False                   False
# 23             3                 True                   False
# 24             2                 True                   False
# 25             2                 True                   False
# 26             3                 True                   False
# 27             1                False                   False
# 28             4                False                   False
# 29             4                False                   False
# 30             1                False                   False
# 31             5                False                   False
# 32             3                 True                   False
# 33             2                 True                   False
# 34             3                 True                   False
# 35             4                 True                   False
# 36             3                 True                   False
# 37             3                 True                   False
#
#     n_of_run_commands  cml_related_commands                     cml_commands  \
# 0                   0                 False                               []
# 1                   0                 False                               []
# 2                   1                  True          [publish, send-comment]
# 3                   1                  True                   [send-comment]
# 4                   1                  True          [publish, send-comment]
# 5                   4                 False                               []
# 6                   1                  True          [publish, send-comment]
# 7                   5                 False                               []
# 8                   3                 False                               []
# 9                   1                  True          [publish, send-comment]
# 10                  1                  True          [publish, send-comment]
# 11                  1                  True                   [send-comment]
# 12                  1                  True          [publish, send-comment]
# 13                  2                  True          [publish, send-comment]
# 14                  1                  True  [tensorboard-dev, send-comment]
# 15                  1                  True          [publish, send-comment]
# 16                  1                  True          [publish, send-comment]
# 17                  1                  True                   [send-comment]
# 18                  1                  True                   [send-comment]
# 19                  3                  True                   [send-comment]
# 20                  2                 False                               []
# 21                  2                 False                               []
# 22                  1                  True          [publish, send-comment]
# 23                  1                  True          [publish, send-comment]
# 24                  2                  True                   [send-comment]
# 25                  2                  True                   [send-comment]
# 26                  1                  True          [publish, send-comment]
# 27                  1                  True          [publish, send-comment]
# 28                  3                 False                               []
# 29                  2                 False                               []
# 30                  1                  True                               []
# 31                  7                 False                               []
# 32                  1                  True          [publish, send-comment]
# 33                  2                  True                   [send-comment]
# 34                  1                  True          [publish, send-comment]
# 35                  2                  True  [runner, publish, send-comment]
# 36                  1                  True          [publish, send-comment]
# 37                  1                  True                   [send-comment]
#
#     docker_related_commands docker_commands
# 0                     False              []
# 1                     False              []
# 2                     False              []
# 3                     False              []
# 4                     False              []
# 5                     False              []
# 6                     False              []
# 7                      True   [build, push]
# 8                     False              []
# 9                     False              []
# 10                    False              []
# 11                    False              []
# 12                    False              []
# 13                    False              []
# 14                    False              []
# 15                    False              []
# 16                    False              []
# 17                    False              []
# 18                    False              []
# 19                    False              []
# 20                    False              []
# 21                    False              []
# 22                    False              []
# 23                    False              []
# 24                    False              []
# 25                    False              []
# 26                    False              []
# 27                    False              []
# 28                    False              []
# 29                    False              []
# 30                    False              []
# 31                    False              []
# 32                    False              []
# 33                    False              []
# 34                    False              []
# 35                    False              []
# 36                    False              []
# 37                    False              []
